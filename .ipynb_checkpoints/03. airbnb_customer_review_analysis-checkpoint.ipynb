# %% [markdown]
# # Data Retrieval

# %%
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import csv
import statsmodels.api as sm
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import json
import pandas as pd
import itertools
import csv
import string
import pickle
import matplotlib.pyplot as plt

from collections import Counter
import re
import spacy
import nltk
from spacy.lang.en import English
from nltk.util import ngrams
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud
import gensim
from gensim import corpora
from gensim.models.ldamodel import LdaModel
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /Users/xzhou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/xzhou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# File path for cities: San Francisco(sf), Okaland(ok), and Santa Clara(sc)

file_url = '/Users/xzhou/github/project_archives/files_airbnb/{}.csv'

sf_file = file_url.format('sf_airbnb/reviews')
ok_file = file_url.format('ok_airbnb/reviews')
sc_file = file_url.format('sc_airbnb/reviews')

# %%
# Loaded review information for each city

reviews_sf = pd.read_csv(sf_file)
reviews_ok = pd.read_csv(ok_file)
reviews_sc = pd.read_csv(sc_file)

# %%
print (reviews_sf.shape, reviews_ok.shape, reviews_sc.shape)
# Out:
# (278884, 6) (78491, 6) (135238, 6)

# %%
# Concatenated all files into one
# Created keys for each file for future references

frames = [reviews_sf, reviews_ok, reviews_sc]
keys = ['reviews_sf', 'reviews_ok', 'reviews_sc']
df_reviews = pd.concat(frames, keys=keys)

# %%
print('df_reviews dimensions: ', df_reviews.shape )
df_reviews.head()
# Out:
# df_reviews dimensions:  (492613, 6)
#               listing_id     id        date  reviewer_id reviewer_name  \
# reviews_sf 0         958   5977  2009-07-23        15695      Edmund C
#            1         958   6660  2009-08-03        26145         Simon
#            2         958  11519  2009-09-27        25839         Denis
#            3         958  16282  2009-11-05        33750          Anna
#            4         958  26008  2010-02-13        15416       Venetia
#
#                                                        comments
# reviews_sf 0  Our experience was, without a doubt, a five st...
#            1  Returning to San Francisco is a rejuvenating t...
#            2  We were very pleased with the accommodations a...
#            3  We highly recommend this accomodation and agre...
#            4  Holly's place was great. It was exactly what I...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Smaller Set of Features

# %%
df_reviews.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
# Kept only 'listing_id' and 'comments' for topic analysis

columns_to_drop=['id', 'date', 'reviewer_id', 'reviewer_name']
df_reviews.drop(columns_to_drop, axis=1, inplace=True)

# %%
df_reviews.shape
# Out:
# (492613, 2)

# %% [markdown]
# ## Add Review Rating Feature

# %%
# Pull the dataset from previous step, which has the rating information

pkl_file = '/Users/xzhou/github/project_archives/files_airbnb/{}.pkl'
listings = pkl_file.format('df_listings_selected_features')

df_listings = pd.read_pickle(listings)

print('df_listings dimensions: :', df_listings.shape)
df_listings.head()
# Out:
# df_listings dimensions: : (9062, 315)
#      id  host_yrs  host_response_rate  host_listings_count  accommodates  \
# 0   958        12                0.92                    1             3
# 1  5858        11                1.00                    2             5
# 2  7918        11                1.00                   10             2
# 3  8142        11                1.00                   10             2
# 4  8567        11                0.80                    1             6
#
#    bathrooms  bedrooms  beds  price  security_deposit        ...         \
# 0        1.0       1.0   2.0  170.0                 1        ...
# 1        1.0       2.0   3.0  235.0                 1        ...
# 2        4.0       1.0   1.0   65.0                 1        ...
# 3        4.0       1.0   1.0   65.0                 1        ...
# 4        1.0       2.0   3.0  255.0                 0        ...
#
#    amenities_Shampoo  amenities_Single level home  amenities_Smoke detector  \
# 0                  1                            0                         1
# 1                  1                            0                         1
# 2                  0                            0                         1
# 3                  0                            0                         1
# 4                  1                            0                         1
#
#    amenities_Stepfree access  amenities_TV  amenities_Wifi  \
# 0                          0             1               1
# 1                          0             0               1
# 2                          0             1               1
# 3                          0             1               1
# 4                          0             1               1
#
#    amenities_translation missing enhosting_amenity_49  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    amenities_translation missing enhosting_amenity_50   ref_district  \
# 0                                                  0   San Francisco
# 1                                                  0   San Francisco
# 2                                                  1   San Francisco
# 3                                                  0   San Francisco
# 4                                                  0   San Francisco
#
#    ref_jurisdiction
# 0     SAN FRANCISCO
# 1     SAN FRANCISCO
# 2     SAN FRANCISCO
# 3     SAN FRANCISCO
# 4     SAN FRANCISCO
#
# [5 rows x 315 columns]

# %%
# Extract unique IDs from above dataset. Focus analysis on those IDs

unique_ids = df_listings.id.unique()

print('Number of unique IDs with rating: ', len(unique_ids))
# Out:
# Number of unique IDs with rating:  9062

# %%
# Filter to smaller datasets for topic analysis

df_reviews = df_reviews[df_reviews['listing_id'].isin(unique_ids)]

df_reviews.shape
# Out:
# (413281, 2)

# %%
df_listings_reviews = pd.merge(left = df_reviews, 
                               right = df_listings,
                               how = 'inner',
                               left_on='listing_id', 
                               right_on='id')

print('df_listings_reviews dimensions: ', df_listings_reviews.shape)
# Out:
# df_listings_reviews dimensions:  (413281, 317)

# %%
# Filter to smaller set of features. 
# The goal is to identify main topics within each sentiment

columns_to_keep = ['listing_id', 'review_scores_rating', 'comments']
df_reviews_smaller = df_listings_reviews[columns_to_keep]
df_reviews_smaller.head()
# Out:
#    listing_id  review_scores_rating  \
# 0         958                  97.0
# 1         958                  97.0
# 2         958                  97.0
# 3         958                  97.0
# 4         958                  97.0
#
#                                             comments
# 0  Our experience was, without a doubt, a five st...
# 1  Returning to San Francisco is a rejuvenating t...
# 2  We were very pleased with the accommodations a...
# 3  We highly recommend this accomodation and agre...
# 4  Holly's place was great. It was exactly what I...

# %% [markdown]
# ## Null Values

# %%
df_reviews_smaller.dropna(inplace=True)

# %%
df_reviews_smaller.isnull().sum()
# Out:
# listing_id              0
# review_scores_rating    0
# comments                0
# dtype: int64

# %% [markdown]
# ## Duplicates

# %%
# Drop any possible duplicate lines before saving the result

df_reviews_smaller.drop_duplicates(inplace=True)
df_reviews_smaller.shape
# Out:
# (412697, 3)

# %% [markdown]
# ## Sentiment Distribution

# %%
# Assign sentiment score based on review ratings

def sentiment_score(x):
    """
    This is to assignment sentiment score based on rating.
    Input: ratings, ranging from 1 to 100
    Ouput: sentimant score, ranging from -1 to +1
           Postive: +1; neutral: 0; negative: -1

    """
    if x >= 70:
        return +1
    elif 50 <= x < 70:
        return 0
    else:
        return -1

# %%
# Break down ratings to positive, neutral, and negative sentiments
# This is to perform analysis for each sentiment

df_reviews_smaller['sentiment_score'] = df_reviews_smaller['review_scores_rating']  \
                                      .apply(lambda x: sentiment_score(x))

df_pos = df_reviews_smaller[df_reviews_smaller['sentiment_score']==1]
df_neg = df_reviews_smaller[df_reviews_smaller['sentiment_score']==0]

print(df_pos.shape, df_neg.shape)
# Out:
# (412439, 4) (224, 4)

# %%
# Noted ratings scores are highly skewed. 
# Topic modeling based on positive and negative sentiment will not work as expected

df_reviews_smaller.review_scores_rating.describe (include='all')
# Out:
# count    412697.000000
# mean         95.914017
# std           3.658173
# min          20.000000
# 25%          95.000000
# 50%          97.000000
# 75%          98.000000
# max         100.000000
# Name: review_scores_rating, dtype: float64

# %%
df_reviews_smaller.review_scores_rating.hist(bins=10)

# %%
# A few examples for reviews with negative sentiment

df_reviews_smaller[df_reviews_smaller.review_scores_rating<50].head()
# Out:
#         listing_id  review_scores_rating  \
# 135527     5286782                  20.0
# 172908     8925997                  20.0
# 207337    14468427                  40.0
# 208525    14575557                  40.0
# 229012    17715373                  40.0
#
#                                                  comments  sentiment_score
# 135527  Unsafe neighborhood. Congested place. No prese...               -1
# 172908       Be ready to have the worst property manager                -1
# 207337  This is not an apartment for a woman by hersel...               -1
# 208525  The place was not as large as advertised but t...               -1
# 229012  Central hostel with good people. Double check ...               -1

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### Review Length

# %%
# Break down reviews by word. 

df_reviews_smaller['comments_words'] = df_reviews_smaller['comments']  \
                                       .apply(nltk.word_tokenize)

# %%
# Perform word count for each review. 
# This is to remove reviews that do not have meaningful leangh

df_reviews_smaller['word_count'] = df_reviews_smaller['comments_words'].apply(len)
df_reviews_smaller.head()
# Out:
#    listing_id  review_scores_rating  \
# 0         958                  97.0
# 1         958                  97.0
# 2         958                  97.0
# 3         958                  97.0
# 4         958                  97.0
#
#                                             comments  sentiment_score  \
# 0  Our experience was, without a doubt, a five st...                1
# 1  Returning to San Francisco is a rejuvenating t...                1
# 2  We were very pleased with the accommodations a...                1
# 3  We highly recommend this accomodation and agre...                1
# 4  Holly's place was great. It was exactly what I...                1
#
#                                       comments_words  word_count
# 0  [Our, experience, was, ,, without, a, doubt, ,...          96
# 1  [Returning, to, San, Francisco, is, a, rejuven...          77
# 2  [We, were, very, pleased, with, the, accommoda...         149
# 3  [We, highly, recommend, this, accomodation, an...          96
# 4  [Holly, 's, place, was, great, ., It, was, exa...          53

# %%
# Keep only comments that have meaningful length

meaningful_length = 10
df_reviews_smaller = df_reviews_smaller[
                     df_reviews_smaller['word_count'] >= meaningful_length]

df_reviews_smaller.shape
# Out:
# (378367, 6)

# %% [markdown]
# ### Consolidate Reviews for Each Apartment

# %%
# Concolidated all reviews belong to a single 'id' to one big comment. 
# This for easier processing later on

df_consol_reviews = df_reviews_smaller  \
                    .groupby('listing_id')  \
                    .comments.apply(lambda x: ' ,'.join(x))  \
                    .reset_index()

df_consol_reviews.head()
# Out:
#    listing_id                                           comments
# 0         958  Our experience was, without a doubt, a five st...
# 1        3083  B- love guest house is a pretty good place, ev...
# 2        3264  The Garden Camper is totally Berkeley. It's ni...
# 3        5739  My wife and I were absolutely thrilled with ou...
# 4        5858  We had a fabulous time staying with Philip and...

# %%
df_consol_reviews.shape
# Out:
# (8950, 2)

# %%
df_final = pd.merge(left = df_consol_reviews, 
                    right = df_reviews_smaller, 
                    how='left', 
                    left_on ='listing_id', 
                    right_on = 'listing_id')

df_final.shape
# Out:
# (378367, 7)

# %%
df_final.head()
# Out:
#    listing_id                                         comments_x  \
# 0         958  Our experience was, without a doubt, a five st...
# 1         958  Our experience was, without a doubt, a five st...
# 2         958  Our experience was, without a doubt, a five st...
# 3         958  Our experience was, without a doubt, a five st...
# 4         958  Our experience was, without a doubt, a five st...
#
#    review_scores_rating                                         comments_y  \
# 0                  97.0  Our experience was, without a doubt, a five st...
# 1                  97.0  Returning to San Francisco is a rejuvenating t...
# 2                  97.0  We were very pleased with the accommodations a...
# 3                  97.0  We highly recommend this accomodation and agre...
# 4                  97.0  Holly's place was great. It was exactly what I...
#
#    sentiment_score                                     comments_words  \
# 0                1  [Our, experience, was, ,, without, a, doubt, ,...
# 1                1  [Returning, to, San, Francisco, is, a, rejuven...
# 2                1  [We, were, very, pleased, with, the, accommoda...
# 3                1  [We, highly, recommend, this, accomodation, an...
# 4                1  [Holly, 's, place, was, great, ., It, was, exa...
#
#    word_count
# 0          96
# 1          77
# 2         149
# 3          96
# 4          53

# %%
# Only keep one consolidated review per Listing ID

df_final.drop_duplicates(subset=['comments_x'], keep='first', inplace=True)

df_final.shape
# Out:
# (8950, 7)

# %%
# Drop columns. 'Comments-words' need to be dropped, as this is
# for individual review, not consolidated review.

columns_to_drop = ['comments_x', 'comments_words', 'word_count']
df_final.drop (columns_to_drop, axis=1, inplace=True)
df_final.head()
# Out:
#      listing_id  review_scores_rating  \
# 0           958                  97.0
# 144        3083                  91.0
# 168        3264                  90.0
# 203        5739                  99.0
# 386        5858                  98.0
#
#                                             comments_y  sentiment_score
# 0    Our experience was, without a doubt, a five st...                1
# 144  B- love guest house is a pretty good place, ev...                1
# 168  The Garden Camper is totally Berkeley. It's ni...                1
# 203  My wife and I were absolutely thrilled with ou...                1
# 386  We had a fabulous time staying with Philip and...                1

# %%
df_final.rename( index=str, columns ={'comments_y': 'consol_reviews'}, inplace=True)
df_final.head()
# Out:
#      listing_id  review_scores_rating  \
# 0           958                  97.0
# 144        3083                  91.0
# 168        3264                  90.0
# 203        5739                  99.0
# 386        5858                  98.0
#
#                                         consol_reviews  sentiment_score
# 0    Our experience was, without a doubt, a five st...                1
# 144  B- love guest house is a pretty good place, ev...                1
# 168  The Garden Camper is totally Berkeley. It's ni...                1
# 203  My wife and I were absolutely thrilled with ou...                1
# 386  We had a fabulous time staying with Philip and...                1

# %%
# Break down consolidated reviews by word. 

df_final['words'] = df_final['consol_reviews'].apply(nltk.word_tokenize)

# %%
# Store the data prior to modeling
# When there are changes, mark file_updated as true. Changes will be
# written to local files. Otherwise, mark file_updated as false. 
# Data will be loaded from existing files

file_updated = True
pkl_file = '/Users/xzhou/github/project_archives/files_airbnb/{}.pkl'
reviews = pkl_file.format('reviews_final')


if file_updated:
    with open(reviews, 'wb') as file:
        pd.to_pickle(df_final, file)
else:
    try: 
        with open(reviews, 'rb') as file:
            df_final = pd.read_pickle(file)
    except:
        with open(reviews, 'wb') as file:
            pd.to_pickle(df_final, file)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Topic Modeling Engine

# %%
# Define a topic modeling engine for intensive modeling. 
# This can help test out models and identify optimal result.

class TopicModelEngine:
    
    def __init__(self, raw_data):
        self.raw_data = raw_data

    def get_lemma(self, word):
        """
        Get the root words
        """
        try:
            lemma = wn.morphy(word)
        except:
            lemma = word
        return lemma
            
    def tokenize(self, text):
        """
        This is to perform word tokenizing. It performs ngram (1,2)
        """
        lda_tokens = []
        text=text.strip().lower()

        # Extract word portion out of sentence and excludes spaace
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(text)
        tokens = [token for token in tokens if (not token.isspace())]

        for token in tokens:
            lda_tokens.append(token)

        # Extract bigrams for additional analysis
        bigrams = ngrams(tokens, 2)

        for bg, count in Counter(bigrams).most_common():
            token_string = []
            token_string = str(bg[0]) + " " + str(bg[1])
            lda_tokens.append(token_string)

        return lda_tokens
    
    def text_processing(self, sentence, stop_words):
        """
        This is to break down text sentence into words, and 
        clean up the words to prepare for LDA modeling.
        """
    
        tokens = self.tokenize(sentence)
        tokens = [word for word in tokens if len(tokens)>5]
        tokens = [word for word in tokens if word.strip() not in stop_words]
        tokens = [self.get_lemma(word) for word in tokens]

        return tokens 
    
    def LDA_preprocessing(self, stop_words):
        """
        Provided with raw data, the proprocessing will automatically prepare and
        clean up the data, and generate necessay documents for LDA's use.
        """
        self.text_data = []

        for line in self.raw_data:
            tokens = self.text_processing(line, stop_words)
            tokens=[token for token in tokens if token is not None]
            self.text_data.append(tokens)
        
        # Create Dictionary
        self.dictionary = corpora.Dictionary(self.text_data)
        # Term Document Frequency
        self.corpus = [self.dictionary.doc2bow(text) for text in self.text_data]

    def LDA_model(self, num_of_topics, num_passes, stop_words):
        """
        This is to perform topic modeling and save the model under the name
        user provides
        """
        self.LDA_preprocessing(stop_words)
        num_topics = num_of_topics
        self.lda = LdaModel(corpus=self.corpus,  
                            num_topics=num_topics, 
                            id2word=self.dictionary, 
                            passes=num_passes) 
        
        #self.lda_corpus = self.lda(self.corpus)
        #self.lda.save(file_name_to_save_as)
        
        return self.lda
    
    def print_topics(self, num_of_words):
        """
        Print out topics for users's decision making. 
        User can specify number of words to print out
        """
        topics = self.lda.print_topics(num_words=num_of_words)
        for topic in topics:
            print('Topic ' + str(topic[0]+1)+': '+str(topic[1]))
            
    def word_cloud(self, num_of_topics):
        for topic in range(num_of_topics):
            plt.figure(figsize=(14,8))
            plt.imshow(WordCloud().fit_words(dict(self.lda.show_topic(topic, 200))))
            plt.axis("off")
            plt.title("Topic #" + str(topic))
            plt.show()

# %% [markdown]
# ## Stop Words

# %%
# Default stop_words
stop_words = set(stopwords.words('English'))

# %%
# This is to add additional words to default stop words
# Additional words: through multiple iterations, addtional stop words were identified
# Default stop: provided by nltk

add_words_to_exclude = set(['get', 'one', 'say', 'still', 'try', 'david', 
                            'john', 'good', 'area', 'oakland','recommend', 
                            'nice', 'la', 'area', 'also', 'thing', 'michael', 
                            'stay', 'us', 'de', 'place', 'house', 'great', 
                            'enjoy','tings', 'another','maybe','around', 'santa',
                            'perfect', 'love', 'well', 'feel', 'amaze', 'even',
                            'definitely', 'check', 'make', 'like', 'take', 'back', 
                            'felt', 'really', 'need', 'highly', 'lovely'])

# %%
# Add additional words to default stop words

all_stop_words = stop_words.union(add_words_to_exclude)

# %% [markdown]
# ## Customer Review Analysis

# %%
X = df_final['consol_reviews']

# %%
# Identify top 3 topics

topics_3 = TopicModelEngine(X)
lda_3 = topics_3.LDA_model(num_of_topics=3, 
                           num_passes=10,
                           stop_words=all_stop_words)
topics_3.print_topics(num_of_words=10)
# Out:
# Topic 1: 0.015*"room" + 0.013*"clean" + 0.013*"location" + 0.012*"close" + 0.011*"restaurant" + 0.011*"apartment" + 0.009*"walk" + 0.009*"street" + 0.009*"kitchen" + 0.009*"bed"
# Topic 2: 0.029*"host" + 0.021*"clean" + 0.019*"home" + 0.015*"comfortable" + 0.014*"location" + 0.014*"stay" + 0.012*"room" + 0.011*"time" + 0.010*"make" + 0.010*"welcome"
# Topic 3: 0.019*"host" + 0.016*"arrival" + 0.016*"days" + 0.011*"reservation" + 0.010*"cancel" + 0.009*"posting" + 0.009*"automate" + 0.008*"issue" + 0.006*"le" + 0.006*"day"

# %%
topics_3.word_cloud(num_of_topics=3)

# %%
# Find out topic for each individual review

for i in lda_3.get_document_topics(topics_3.corpus):
    print (i)
# Out:
# [(0, 0.53956914), (1, 0.4514777)]
# [(0, 0.4453028), (1, 0.5058931), (2, 0.048804056)]
# [(0, 0.018172968), (1, 0.96471435), (2, 0.017112695)]
# [(0, 0.33885542), (1, 0.64696443), (2, 0.014180115)]
# [(0, 0.011195947), (1, 0.977953), (2, 0.010851063)]
# [(0, 0.29606074), (1, 0.6473781), (2, 0.056561183)]
# [(0, 0.1576438), (1, 0.5708874), (2, 0.27146882)]
# [(0, 0.297784), (1, 0.69328284)]
# [(0, 0.02448116), (1, 0.9522804), (2, 0.023238424)]
# [(0, 0.0120441625), (1, 0.8309127), (2, 0.15704317)]
# [(0, 0.040121716), (1, 0.9224024), (2, 0.037475932)]
# [(0, 0.6887285), (1, 0.252258), (2, 0.059013482)]
# [(0, 0.40069818), (1, 0.5888422), (2, 0.0104596205)]
# [(0, 0.061276678), (1, 0.8790347), (2, 0.059688628)]
# [(0, 0.08882672), (1, 0.8135905), (2, 0.09758274)]
# [(0, 0.34208587), (1, 0.630831), (2, 0.027083121)]
# [(0, 0.46307698), (1, 0.37029615), (2, 0.1666269)]
# [(0, 0.33393413), (1, 0.6469282), (2, 0.019137723)]
# [(0, 0.61155736), (1, 0.11105076), (2, 0.27739185)]
# [(0, 0.89740396), (1, 0.07781792), (2, 0.024778105)]
# [(0, 0.32833794), (1, 0.65610504), (2, 0.015557007)]
# [(0, 0.23088819), (1, 0.3122118), (2, 0.4569)]
# [(0, 0.23401172), (1, 0.75665194)]
# [(0, 0.017990071), (1, 0.9656606), (2, 0.016349338)]
# [(0, 0.01565215), (1, 0.9699396), (2, 0.014408282)]
# [(0, 0.8157648), (1, 0.17406566), (2, 0.010169548)]
# [(0, 0.17573233), (1, 0.80888563), (2, 0.015382062)]
# [(1, 0.98167074)]
# [(0, 0.13948229), (1, 0.8325716), (2, 0.027946102)]
# [(0, 0.029427908), (1, 0.7617839), (2, 0.20878817)]
# [(0, 0.9313014), (1, 0.05642604), (2, 0.012272588)]
# [(0, 0.7732641), (1, 0.21436843), (2, 0.012367443)]
# [(0, 0.3480405), (1, 0.6453045)]
# [(0, 0.3725042), (1, 0.5349662), (2, 0.09252961)]
# [(1, 0.9155061), (2, 0.076084025)]
# [(0, 0.34457114), (1, 0.6041239), (2, 0.051304955)]
# [(0, 0.5315203), (1, 0.39772204), (2, 0.07075761)]
# [(0, 0.46180636), (1, 0.47543323), (2, 0.06276038)]
# [(0, 0.35454163), (1, 0.6287208), (2, 0.016737541)]
# [(0, 0.44333896), (1, 0.34483966), (2, 0.21182142)]
# [(0, 0.76294875), (1, 0.19956565), (2, 0.037485603)]
# [(0, 0.066173375), (1, 0.9226214), (2, 0.011205127)]
# [(0, 0.6396174), (1, 0.33455098), (2, 0.025831684)]
# [(0, 0.27239856), (1, 0.71131694), (2, 0.0162845)]
# [(0, 0.3968684), (1, 0.38529074), (2, 0.21784082)]
# [(0, 0.79083085), (1, 0.17746809), (2, 0.031701043)]
# [(0, 0.44312707), (1, 0.5333029), (2, 0.023570014)]
# [(0, 0.4124012), (1, 0.42682028), (2, 0.16077854)]
# [(0, 0.88533974), (1, 0.0964535), (2, 0.018206805)]
# [(0, 0.9649325), (1, 0.019933533), (2, 0.015133956)]
# [(0, 0.7445474), (1, 0.24059401), (2, 0.014858578)]
# [(0, 0.58652145), (1, 0.22152199), (2, 0.19195661)]
# [(0, 0.01642413), (1, 0.9690053), (2, 0.014570548)]
# [(0, 0.120087095), (1, 0.78747666), (2, 0.09243627)]
# [(0, 0.81968856), (1, 0.09584639), (2, 0.084465064)]
# [(0, 0.019553239), (1, 0.9525946), (2, 0.02785219)]
# [(0, 0.5080595), (1, 0.43189132), (2, 0.060049202)]
# [(0, 0.01284453), (1, 0.9733756), (2, 0.013779852)]
# [(0, 0.31334916), (1, 0.646516), (2, 0.04013487)]
# [(0, 0.6337531), (2, 0.36451483)]
# [(0, 0.14567028), (1, 0.63383484), (2, 0.2204949)]
# [(0, 0.28483528), (1, 0.7019299), (2, 0.013234765)]
# [(0, 0.025443906), (1, 0.9507896), (2, 0.02376649)]
# [(0, 0.33577588), (1, 0.46648255), (2, 0.1977416)]
# [(0, 0.3268836), (1, 0.6423938), (2, 0.03072254)]
# [(0, 0.58452404), (1, 0.4069654)]
# [(0, 0.29458848), (1, 0.095495015), (2, 0.6099165)]
# [(0, 0.03921367), (1, 0.9167434), (2, 0.044042908)]
# [(0, 0.18624611), (1, 0.20114695), (2, 0.61260694)]
# [(0, 0.21128294), (1, 0.7722137), (2, 0.01650336)]
# [(0, 0.038483743), (1, 0.9276047), (2, 0.033911534)]
# [(0, 0.021020595), (1, 0.9405816), (2, 0.03839778)]
# [(0, 0.028519526), (1, 0.7360526), (2, 0.2354279)]
# [(0, 0.061490525), (1, 0.86480093), (2, 0.07370853)]
# [(0, 0.54994005), (1, 0.44550908)]
# [(0, 0.5418826), (1, 0.40816486), (2, 0.04995254)]
# [(0, 0.0570772), (1, 0.8842099), (2, 0.0587129)]
# [(0, 0.025193851), (1, 0.95304817), (2, 0.021758048)]
# [(0, 0.7946603), (1, 0.17365557), (2, 0.031684127)]
# [(0, 0.34785953), (1, 0.63289744), (2, 0.019243069)]
# [(0, 0.90799147), (2, 0.084648624)]
# [(0, 0.8005236), (1, 0.17505892), (2, 0.024417493)]
# [(0, 0.6321365), (1, 0.354109), (2, 0.01375444)]
# [(0, 0.83322644), (1, 0.16027248)]
# [(0, 0.35561815), (1, 0.637783)]
# [(0, 0.039278354), (1, 0.92251164), (2, 0.038210034)]
# [(0, 0.646323), (1, 0.34620628)]
# [(0, 0.66057223), (1, 0.2912673), (2, 0.048160482)]
# [(0, 0.3665382), (1, 0.6232125), (2, 0.010249244)]
# [(0, 0.37855405), (1, 0.6057819), (2, 0.015664022)]
# [(0, 0.56445163), (1, 0.42680755)]
# [(0, 0.030036015), (1, 0.9414936), (2, 0.028470356)]
# [(0, 0.015460886), (1, 0.9699015), (2, 0.014637648)]
# [(0, 0.03563253), (1, 0.9299529), (2, 0.034414597)]
# [(0, 0.17794204), (1, 0.63699335), (2, 0.18506463)]
# [(0, 0.89690244), (1, 0.09556255)]
# [(0, 0.02915092), (1, 0.9418791), (2, 0.028969934)]
# [(0, 0.08993806), (1, 0.9039617)]
# [(0, 0.0126974415), (1, 0.97203434), (2, 0.015268269)]
# [(0, 0.014148059), (1, 0.89222175), (2, 0.09363016)]
# [(0, 0.45862737), (1, 0.51705813), (2, 0.024314553)]
# [(0, 0.40930113), (1, 0.5714681), (2, 0.019230805)]
# [(0, 0.5919646), (1, 0.4002704)]
# [(0, 0.5834247), (1, 0.39193365), (2, 0.024641711)]
# [(0, 0.5525051), (1, 0.37183666), (2, 0.07565823)]
# [(0, 0.61901027), (1, 0.23926455), (2, 0.14172521)]
# [(0, 0.84700465), (1, 0.10464285), (2, 0.04835251)]
# [(0, 0.8838085), (1, 0.09974459), (2, 0.016446942)]
# [(0, 0.30213246), (1, 0.68306214), (2, 0.014805351)]
# [(0, 0.031332683), (1, 0.9384586), (2, 0.030208694)]
# [(0, 0.78501946), (1, 0.20934525)]
# [(0, 0.03713642), (1, 0.03806361), (2, 0.9247999)]
# [(0, 0.7344559), (1, 0.2491403), (2, 0.016403766)]
# [(0, 0.33500075), (1, 0.52559435), (2, 0.13940485)]
# [(0, 0.82836497), (1, 0.01493612), (2, 0.15669893)]
# [(0, 0.7048653), (1, 0.13862738), (2, 0.15650733)]
# [(0, 0.59912986), (1, 0.3920838)]
# [(0, 0.28493175), (1, 0.6993223), (2, 0.015745966)]
# [(0, 0.9834872)]
# [(0, 0.04997714), (1, 0.90125585), (2, 0.048767053)]
# [(0, 0.87103677), (2, 0.12049839)]
# [(0, 0.7437775), (1, 0.23738253), (2, 0.018839989)]
# [(0, 0.3856342), (1, 0.5984399), (2, 0.015925871)]
# [(0, 0.7069731), (1, 0.17982374), (2, 0.113203175)]
# [(0, 0.8827366), (1, 0.017181108), (2, 0.100082256)]
# [(0, 0.010990433), (1, 0.9794751)]
# [(0, 0.7584933), (1, 0.22066635), (2, 0.020840334)]
# [(0, 0.23424327), (1, 0.75100434), (2, 0.014752402)]
# [(0, 0.014475024), (1, 0.97223485), (2, 0.0132901305)]
# [(0, 0.5843079), (1, 0.3929774), (2, 0.022714691)]
# [(0, 0.96267337), (1, 0.032979004)]
# [(0, 0.35150486), (1, 0.63366824), (2, 0.0148269255)]
# [(0, 0.032973606), (1, 0.72571844), (2, 0.24130797)]
# [(0, 0.3105506), (1, 0.6706657), (2, 0.01878373)]
# [(0, 0.5845339), (1, 0.34488913), (2, 0.07057699)]
# [(0, 0.023358734), (1, 0.89410025), (2, 0.08254097)]
# [(0, 0.77979755), (1, 0.20729168), (2, 0.012910815)]
# [(0, 0.17647848), (1, 0.78051853), (2, 0.04300304)]
# [(0, 0.5572684), (1, 0.42942756), (2, 0.013304024)]
# [(0, 0.02359133), (1, 0.95345366), (2, 0.022955017)]
# [(0, 0.48655298), (1, 0.51012975)]
# [(0, 0.5448732), (1, 0.34905806), (2, 0.10606873)]
# [(0, 0.97971314), (1, 0.010586672)]
# [(0, 0.24351245), (1, 0.6788808), (2, 0.07760672)]
# [(0, 0.4164402), (1, 0.41526824), (2, 0.16829152)]
# [(0, 0.46494657), (1, 0.52394694), (2, 0.0111064445)]
# [(0, 0.74841976), (1, 0.23552091), (2, 0.01605932)]
# [(0, 0.77987874), (1, 0.21193658)]
# [(0, 0.114044555), (1, 0.8737324), (2, 0.012223007)]
# [(0, 0.9092037), (1, 0.0594923), (2, 0.031304028)]
# [(0, 0.2627331), (1, 0.72609574), (2, 0.011171145)]
# [(0, 0.019379934), (1, 0.96279514), (2, 0.017824892)]
# [(0, 0.22161624), (1, 0.6646948), (2, 0.11368896)]
# [(0, 0.5175386), (1, 0.27550787), (2, 0.20695356)]
# [(0, 0.0307259), (1, 0.68292177), (2, 0.28635228)]
# [(0, 0.012089423), (1, 0.8949574), (2, 0.09295319)]
# [(0, 0.7240597), (1, 0.23835164), (2, 0.037588656)]
# [(0, 0.21031065), (1, 0.77513427), (2, 0.014555092)]
# [(0, 0.3868641), (1, 0.60756594)]
# [(0, 0.7594116), (1, 0.20751427), (2, 0.033074126)]
# [(0, 0.028229736), (1, 0.94646174), (2, 0.025308492)]
# [(0, 0.037555594), (1, 0.9313083), (2, 0.031136101)]
# [(0, 0.0292662), (1, 0.94224286), (2, 0.028490944)]
# [(0, 0.12629592), (1, 0.8344263), (2, 0.03927782)]
# [(0, 0.18882422), (1, 0.79308045), (2, 0.018095346)]
# [(0, 0.50312996), (1, 0.4641595), (2, 0.032710567)]
# [(0, 0.6983246), (1, 0.28902048), (2, 0.012654853)]
# [(0, 0.8852568), (1, 0.11065899)]
# [(0, 0.26242644), (1, 0.6125544), (2, 0.1250192)]
# [(0, 0.029790375), (1, 0.72432894), (2, 0.24588074)]
# [(0, 0.93855983), (1, 0.055156253)]
# [(0, 0.69616014), (1, 0.2945478)]
# [(0, 0.027293496), (1, 0.9469609), (2, 0.025745522)]
# [(0, 0.76963365), (1, 0.2231319)]
# [(0, 0.8930893), (1, 0.059202798), (2, 0.047707886)]
# [(0, 0.48074764), (1, 0.5148278)]
# [(0, 0.35799205), (1, 0.62941337), (2, 0.012594573)]
# [(0, 0.502327), (1, 0.27201286), (2, 0.2256601)]
# [(0, 0.41936728), (1, 0.48007104), (2, 0.10056165)]
# [(0, 0.041675553), (1, 0.04167217), (2, 0.9166523)]
# [(0, 0.22700444), (1, 0.59523803), (2, 0.17775756)]
# [(1, 0.65996754), (2, 0.3344247)]
# [(0, 0.34499177), (1, 0.62706363), (2, 0.027944587)]
# [(0, 0.4182367), (1, 0.5540437), (2, 0.027719544)]
# [(0, 0.15884122), (1, 0.8332496)]
# [(0, 0.15259601), (1, 0.8248567), (2, 0.022547303)]
# [(0, 0.9414548), (1, 0.030472869), (2, 0.028072342)]
# [(0, 0.636815), (1, 0.31945902), (2, 0.043725926)]
# [(0, 0.4995506), (1, 0.48256508), (2, 0.017884266)]
# [(0, 0.013484032), (1, 0.87915987), (2, 0.107356116)]
# [(0, 0.47956416), (1, 0.51261014)]
# [(0, 0.014598168), (1, 0.74366593), (2, 0.24173594)]
# [(0, 0.02226745), (1, 0.8915133), (2, 0.08621927)]
# [(0, 0.41033727), (1, 0.5493087), (2, 0.04035399)]
# [(0, 0.014611087), (1, 0.75061065), (2, 0.23477824)]
# [(0, 0.20371321), (1, 0.78389263), (2, 0.012394128)]
# [(0, 0.95542043), (1, 0.012143772), (2, 0.03243582)]
# [(0, 0.027697576), (1, 0.81287414), (2, 0.15942828)]
# [(0, 0.025921304), (1, 0.9521601), (2, 0.021918554)]
# [(0, 0.643271), (1, 0.34844613)]
# [(0, 0.5784665), (1, 0.41270286)]
# [(0, 0.79148674), (1, 0.1980846), (2, 0.01042866)]
# [(0, 0.83061457), (1, 0.1503931), (2, 0.01899238)]
# [(0, 0.8130883), (1, 0.18466699)]
# [(0, 0.83641493), (1, 0.030878412), (2, 0.13270663)]
# [(0, 0.8521085), (1, 0.1268655), (2, 0.02102602)]
# [(0, 0.04244638), (1, 0.041840404), (2, 0.91571325)]
# [(0, 0.45674562), (1, 0.41599914), (2, 0.12725523)]
# [(0, 0.6295924), (1, 0.3331993), (2, 0.03720828)]
# [(0, 0.011435737), (1, 0.75511014), (2, 0.23345414)]
# [(0, 0.16749631), (1, 0.8089857), (2, 0.023517963)]
# [(0, 0.71154195), (1, 0.20951982), (2, 0.07893827)]
# [(0, 0.6580199), (1, 0.21722372), (2, 0.124756396)]
# [(0, 0.71367025), (1, 0.2742085), (2, 0.012121263)]
# [(0, 0.47498477), (1, 0.461025), (2, 0.06399026)]
# [(0, 0.40112048), (1, 0.49600896), (2, 0.102870554)]
# [(0, 0.026310567), (1, 0.9505426), (2, 0.023146795)]
# [(0, 0.02540224), (1, 0.69750756), (2, 0.2770902)]
# [(0, 0.4007715), (1, 0.5778445), (2, 0.02138396)]
# [(0, 0.012281792), (1, 0.97587526), (2, 0.011842973)]
# [(0, 0.90701866), (1, 0.016973406), (2, 0.076007925)]
# [(0, 0.74815804), (1, 0.24402373)]
# [(0, 0.8319104), (1, 0.056474324), (2, 0.111615315)]
# [(0, 0.04572802), (1, 0.91699135), (2, 0.037280604)]
# [(0, 0.010052467), (1, 0.9808329)]
# [(0, 0.5531955), (1, 0.40664363), (2, 0.040160913)]
# [(0, 0.022094456), (1, 0.9606016), (2, 0.017303906)]
# [(0, 0.30731517), (1, 0.6749696), (2, 0.017715191)]
# [(0, 0.52112657), (1, 0.47014773)]
# [(0, 0.16935615), (1, 0.6372506), (2, 0.1933933)]
# [(0, 0.42809716), (1, 0.26546052), (2, 0.30644238)]
# [(0, 0.01698315), (1, 0.9662911), (2, 0.016725674)]
# [(0, 0.9579253), (1, 0.02488298), (2, 0.017191699)]
# [(0, 0.10429475), (1, 0.84221226), (2, 0.053493008)]
# [(0, 0.40946686), (1, 0.43477196), (2, 0.15576118)]
# [(0, 0.67873317), (1, 0.28887978), (2, 0.032387078)]
# [(0, 0.29569036), (1, 0.6925692), (2, 0.011740409)]
# [(0, 0.64448565), (1, 0.2458958), (2, 0.10961853)]
# [(0, 0.07946477), (1, 0.87811935), (2, 0.042415813)]
# [(0, 0.42326504), (1, 0.567027)]
# [(0, 0.015110151), (1, 0.9721237), (2, 0.012766185)]
# [(0, 0.021565592), (1, 0.95800066), (2, 0.020433761)]
# [(0, 0.8863935), (1, 0.10795061)]
# [(0, 0.3202983), (1, 0.33617702), (2, 0.34352466)]
# [(0, 0.48354098), (1, 0.08972143), (2, 0.42673764)]
# [(0, 0.6242487), (1, 0.3233382), (2, 0.052413076)]
# [(0, 0.14349101), (1, 0.8500015)]
# [(0, 0.23763157), (1, 0.5821186), (2, 0.18024985)]
# [(0, 0.4013395), (1, 0.55565256), (2, 0.04300795)]
# [(0, 0.03063543), (1, 0.7180993), (2, 0.2512653)]
# [(0, 0.042403013), (1, 0.9206897), (2, 0.03690727)]
# [(0, 0.39127934), (1, 0.419257), (2, 0.18946373)]
# [(0, 0.37525383), (1, 0.6186701)]
# [(1, 0.98677367)]
# [(0, 0.48888925), (1, 0.3058689), (2, 0.20524192)]
# [(0, 0.015977262), (1, 0.12028701), (2, 0.86373574)]
# [(0, 0.66733664), (1, 0.31475568), (2, 0.01790771)]
# [(0, 0.43974167), (1, 0.34522), (2, 0.21503834)]
# [(0, 0.49656507), (1, 0.4964586)]
# [(0, 0.13830069), (1, 0.84635746), (2, 0.015341845)]
# [(0, 0.5759743), (1, 0.41756055)]
# [(0, 0.9186828), (1, 0.043080308), (2, 0.038236875)]
# [(0, 0.6075923), (1, 0.37361276), (2, 0.018795)]
# [(0, 0.38957483), (1, 0.588056), (2, 0.022369158)]
# [(0, 0.11259334), (1, 0.69033295), (2, 0.19707371)]
# [(0, 0.39132264), (1, 0.52311504), (2, 0.08556229)]
# [(0, 0.76183635), (1, 0.23061745)]
# [(0, 0.6047847), (1, 0.2676384), (2, 0.12757687)]
# [(0, 0.78046536), (1, 0.16347598), (2, 0.05605864)]
# [(0, 0.03823917), (1, 0.038056433), (2, 0.9237044)]
# [(0, 0.03910946), (1, 0.92686844), (2, 0.034022108)]
# [(1, 0.8774194), (2, 0.116104096)]
# [(0, 0.01805842), (1, 0.95886695), (2, 0.02307459)]
# [(0, 0.9455047), (1, 0.027608424), (2, 0.026886893)]
# [(0, 0.051456824), (1, 0.9105394), (2, 0.03800379)]
# [(0, 0.5737407), (1, 0.40802833), (2, 0.018230943)]
# [(0, 0.012750321), (1, 0.80343366), (2, 0.18381599)]
# [(0, 0.9449572), (1, 0.02873527), (2, 0.026307575)]
# [(0, 0.03738114), (1, 0.038153574), (2, 0.9244653)]
# [(0, 0.78727156), (1, 0.20778227)]
# [(0, 0.018434962), (1, 0.96464443), (2, 0.016920634)]
# [(0, 0.22625446), (1, 0.3831575), (2, 0.39058805)]
# [(0, 0.17980698), (1, 0.67989457), (2, 0.1402984)]
# [(0, 0.5353955), (1, 0.4499746), (2, 0.014629884)]
# [(0, 0.027064225), (1, 0.9469242), (2, 0.02601154)]
# [(0, 0.5101287), (1, 0.4578444), (2, 0.032026973)]
# [(0, 0.23070331), (1, 0.6823192), (2, 0.08697749)]
# [(0, 0.0693007), (1, 0.44298697), (2, 0.48771235)]
# [(0, 0.4262458), (1, 0.24703828), (2, 0.3267159)]
# [(0, 0.44838023), (1, 0.5361024), (2, 0.015517382)]
# [(0, 0.4963204), (1, 0.41125402), (2, 0.09242559)]
# [(0, 0.2107544), (1, 0.42893273), (2, 0.36031288)]
# [(0, 0.04512669), (1, 0.88970876), (2, 0.06516453)]
# [(0, 0.43879592), (1, 0.5410462), (2, 0.02015792)]
# [(0, 0.046137), (1, 0.9247558), (2, 0.029107217)]
# [(0, 0.19717982), (1, 0.7526678), (2, 0.050152373)]
# [(0, 0.43317375), (1, 0.3848002), (2, 0.18202609)]
# [(0, 0.3370109), (1, 0.649176), (2, 0.013813125)]
# [(0, 0.91251713), (1, 0.045215093), (2, 0.042267803)]
# [(0, 0.63417673), (1, 0.35771504)]
# [(0, 0.3398743), (1, 0.6492821), (2, 0.010843593)]
# [(0, 0.58089155), (1, 0.40578145), (2, 0.013326991)]
# [(0, 0.41545773), (1, 0.56247467), (2, 0.02206763)]
# [(0, 0.052714314), (1, 0.89812577), (2, 0.049159937)]
# [(0, 0.32383686), (1, 0.671052)]
# [(0, 0.2706932), (1, 0.7170506), (2, 0.012256175)]
# [(0, 0.017368829), (1, 0.96540385), (2, 0.017227367)]
# [(0, 0.61494666), (1, 0.380436)]
# [(0, 0.014996306), (1, 0.97105116), (2, 0.013952495)]
# [(0, 0.7880074), (1, 0.19815432), (2, 0.013838334)]
# [(0, 0.114523984), (1, 0.7758854), (2, 0.10959062)]
# [(0, 0.511899), (1, 0.44027385), (2, 0.047827214)]
# [(0, 0.017780023), (1, 0.963617), (2, 0.01860294)]
# [(0, 0.012143858), (1, 0.97539234), (2, 0.012463822)]
# [(0, 0.030525269), (1, 0.94051415), (2, 0.028960556)]
# [(0, 0.4509713), (1, 0.540798)]
# [(0, 0.012522855), (1, 0.97931474)]
# [(0, 0.02745451), (1, 0.9505625), (2, 0.021983042)]
# [(0, 0.6465111), (1, 0.14568244), (2, 0.20780651)]
# [(0, 0.9587115), (1, 0.021270338), (2, 0.020018158)]
# [(0, 0.7149567), (1, 0.27283612), (2, 0.012207166)]
# [(0, 0.052378923), (1, 0.9138907), (2, 0.033730324)]
# [(0, 0.20209226), (1, 0.73757327), (2, 0.0603345)]
# [(0, 0.7457427), (1, 0.21954474), (2, 0.03471253)]
# [(0, 0.40801412), (1, 0.5654533), (2, 0.02653259)]
# [(0, 0.20084246), (1, 0.7895423)]
# [(0, 0.03263893), (1, 0.9358269), (2, 0.03153418)]
# [(0, 0.32347548), (1, 0.66928184)]
# [(0, 0.7189959), (1, 0.25695854), (2, 0.024045527)]
# [(0, 0.25806668), (1, 0.67084736), (2, 0.07108597)]
# [(0, 0.39068758), (1, 0.47420156), (2, 0.13511086)]
# [(0, 0.47001904), (1, 0.5247195)]
# [(0, 0.10448851), (1, 0.76513284), (2, 0.13037859)]
# [(0, 0.010774506), (1, 0.9756883), (2, 0.0135372635)]
# [(0, 0.2409428), (1, 0.7497626)]
# [(0, 0.28592247), (1, 0.6938709), (2, 0.02020662)]
# [(0, 0.68698186), (1, 0.30229795), (2, 0.0107201785)]
# [(0, 0.51065236), (1, 0.40984726), (2, 0.07950038)]
# [(0, 0.15332913), (1, 0.7580543), (2, 0.088616535)]
# [(0, 0.71355516), (1, 0.2782712)]
# [(0, 0.08113018), (1, 0.9017601), (2, 0.017109696)]
# [(0, 0.5510841), (1, 0.43625498), (2, 0.0126608815)]
# [(0, 0.847969), (1, 0.020352473), (2, 0.13167852)]
# [(0, 0.06479367), (1, 0.88676924), (2, 0.048437122)]
# [(0, 0.035191886), (1, 0.9359652), (2, 0.028842974)]
# [(0, 0.19597226), (1, 0.77429044), (2, 0.029737296)]
# [(0, 0.8006436), (1, 0.19286549)]
# [(0, 0.04167168), (1, 0.041671775), (2, 0.9166565)]
# [(0, 0.8686088), (1, 0.10567385), (2, 0.025717376)]
# [(0, 0.6702188), (1, 0.3192917), (2, 0.010489444)]
# [(0, 0.946045), (1, 0.045175485)]
# [(0, 0.50275207), (1, 0.48505753), (2, 0.012190388)]
# [(0, 0.34471563), (1, 0.6416671), (2, 0.013617229)]
# [(0, 0.31695688), (1, 0.67556673)]
# [(0, 0.028019689), (1, 0.65458673), (2, 0.3173936)]
# [(0, 0.16653384), (1, 0.812232), (2, 0.02123411)]
# [(0, 0.5829333), (1, 0.2182322), (2, 0.19883451)]
# [(0, 0.24795727), (1, 0.31018308), (2, 0.4418597)]
# [(0, 0.4346115), (1, 0.22610515), (2, 0.33928338)]
# [(0, 0.684623), (1, 0.2557952), (2, 0.059581794)]
# [(0, 0.04275032), (1, 0.9149089), (2, 0.042340774)]
# [(0, 0.014081927), (1, 0.97347736), (2, 0.012440705)]
# [(0, 0.17569375), (1, 0.81183237), (2, 0.012473855)]
# [(0, 0.33262253), (1, 0.6576237)]
# [(0, 0.86674196), (1, 0.09379994), (2, 0.039458062)]
# [(0, 0.5421717), (1, 0.45269212)]
# [(0, 0.94568443), (1, 0.02884992), (2, 0.02546563)]
# [(0, 0.7244548), (1, 0.26578557)]
# [(0, 0.4140366), (1, 0.5822073)]
# [(0, 0.040020145), (1, 0.92205375), (2, 0.037926093)]
# [(0, 0.6821222), (1, 0.24885169), (2, 0.06902612)]
# [(0, 0.16195722), (1, 0.83197725)]
# [(0, 0.36001402), (1, 0.6298935), (2, 0.010092486)]
# [(0, 0.019672614), (1, 0.9613767), (2, 0.018950654)]
# [(0, 0.012338255), (1, 0.82981396), (2, 0.15784782)]
# [(0, 0.77240145), (1, 0.21746314), (2, 0.010135444)]
# [(0, 0.49142995), (1, 0.48782036), (2, 0.020749658)]
# [(0, 0.14607617), (1, 0.7365776), (2, 0.1173463)]
# [(0, 0.014416093), (1, 0.9707448), (2, 0.014839112)]
# [(0, 0.21496117), (1, 0.73729), (2, 0.047748834)]
# [(0, 0.797417), (1, 0.1575958), (2, 0.0449872)]
# [(0, 0.51717263), (1, 0.43785313), (2, 0.044974264)]
# [(0, 0.33832708), (1, 0.5967448), (2, 0.06492814)]
# [(0, 0.13553086), (1, 0.014048212), (2, 0.85042095)]
# [(0, 0.026885755), (1, 0.9480175), (2, 0.025096804)]
# [(0, 0.7105188), (1, 0.2219027), (2, 0.06757853)]
# [(0, 0.22463913), (1, 0.7619647), (2, 0.013396193)]
# [(0, 0.6100144), (1, 0.3694873), (2, 0.020498348)]
# [(0, 0.2218201), (1, 0.6802265), (2, 0.09795343)]
# [(0, 0.34488463), (1, 0.6275872), (2, 0.027528193)]
# [(0, 0.21744213), (1, 0.5253475), (2, 0.25721037)]
# [(0, 0.044152502), (1, 0.89713824), (2, 0.058709264)]
# [(0, 0.4103832), (1, 0.5189596), (2, 0.07065726)]
# [(0, 0.85146415), (1, 0.08097063), (2, 0.06756522)]
# [(0, 0.9609283), (1, 0.020162858), (2, 0.018908791)]
# [(0, 0.39889157), (1, 0.58976513), (2, 0.011343278)]
# [(0, 0.31503093), (1, 0.6727571), (2, 0.012211982)]
# [(0, 0.04699175), (1, 0.7796249), (2, 0.17338343)]
# [(0, 0.46448314), (1, 0.5066481), (2, 0.028868735)]
# [(0, 0.67627573), (1, 0.26240143), (2, 0.061322846)]
# [(0, 0.15931255), (1, 0.011382207), (2, 0.8293053)]
# [(0, 0.040379807), (1, 0.70382375), (2, 0.2557965)]
# [(0, 0.14707398), (1, 0.84527105)]
# [(0, 0.3371035), (1, 0.6508793), (2, 0.012017189)]
# [(0, 0.08721394), (1, 0.89827883), (2, 0.014507188)]
# [(0, 0.034494538), (1, 0.93149644), (2, 0.03400903)]
# [(0, 0.1165384), (1, 0.77216464), (2, 0.111296974)]
# [(0, 0.21753901), (1, 0.4885897), (2, 0.2938713)]
# [(0, 0.10737116), (2, 0.88478535)]
# [(0, 0.017038384), (1, 0.9224241), (2, 0.06053753)]
# [(0, 0.47836888), (1, 0.27255845), (2, 0.24907264)]
# [(0, 0.5105818), (1, 0.15117937), (2, 0.3382389)]
# [(0, 0.40276572), (1, 0.57755065), (2, 0.019683661)]
# [(0, 0.65197796), (1, 0.25068647), (2, 0.09733557)]
# [(1, 0.8841335), (2, 0.109540366)]
# [(0, 0.10041346), (1, 0.7417921), (2, 0.1577945)]
# [(0, 0.45188296), (1, 0.47095135), (2, 0.077165745)]
# [(0, 0.329774), (1, 0.62855756), (2, 0.041668437)]
# [(0, 0.7865297), (1, 0.021667153), (2, 0.19180308)]
# [(0, 0.021038672), (1, 0.96030414), (2, 0.01865718)]
# [(0, 0.034086388), (1, 0.9405869), (2, 0.02532667)]
# [(0, 0.3311617), (1, 0.6337375), (2, 0.0351008)]
# [(0, 0.56993717), (1, 0.3288095), (2, 0.10125336)]
# [(0, 0.38950107), (1, 0.5951829), (2, 0.015316025)]
# [(0, 0.44100645), (1, 0.52163225), (2, 0.037361316)]
# [(0, 0.016175788), (1, 0.68151695), (2, 0.3023073)]
# [(0, 0.7275343), (1, 0.021045743), (2, 0.25142)]
# [(0, 0.36641425), (1, 0.16585778), (2, 0.46772802)]
# [(0, 0.45422778), (1, 0.53803617)]
# [(0, 0.5107573), (1, 0.48366308)]
# [(0, 0.28984588), (1, 0.7002285)]
# [(0, 0.49435794), (1, 0.35640118), (2, 0.14924091)]
# [(0, 0.021268003), (1, 0.9575523), (2, 0.0211797)]
# [(0, 0.018731594), (1, 0.966633), (2, 0.014635428)]
# [(0, 0.36901012), (1, 0.56035364), (2, 0.07063623)]
# [(0, 0.0144430585), (1, 0.6969018), (2, 0.28865513)]
# [(0, 0.09453652), (1, 0.88899016), (2, 0.01647332)]
# [(0, 0.39705384), (1, 0.59176385), (2, 0.01118228)]
# [(0, 0.018834619), (1, 0.9607001), (2, 0.020465273)]
# [(0, 0.7564919), (1, 0.23634471)]
# [(0, 0.52865785), (1, 0.4347785), (2, 0.03656367)]
# [(0, 0.91633403), (1, 0.07714552)]
# [(0, 0.48401958), (1, 0.49875325), (2, 0.01722721)]
# [(0, 0.55257213), (1, 0.44073224)]
# [(0, 0.021064766), (1, 0.90311635), (2, 0.07581885)]
# [(0, 0.34772024), (1, 0.6395676), (2, 0.0127121275)]
# [(0, 0.013413122), (1, 0.97328955), (2, 0.013297355)]
# [(0, 0.022895154), (1, 0.8729576), (2, 0.104147255)]
# [(0, 0.3437738), (1, 0.6474694)]
# [(0, 0.030556599), (1, 0.94933575), (2, 0.020107586)]
# [(0, 0.6831614), (1, 0.30446213), (2, 0.012376547)]
# [(0, 0.73593825), (1, 0.24611044), (2, 0.017951325)]
# [(0, 0.20888239), (1, 0.78525794)]
# [(0, 0.3647382), (1, 0.35503262), (2, 0.2802292)]
# [(1, 0.7998916), (2, 0.19362563)]
# [(0, 0.41181445), (1, 0.5716489), (2, 0.016536672)]
# [(0, 0.01721163), (1, 0.7286312), (2, 0.2541571)]
# [(0, 0.0282378), (1, 0.9450042), (2, 0.026757948)]
# [(0, 0.05468494), (1, 0.81455094), (2, 0.13076414)]
# [(0, 0.8318801), (1, 0.15819474)]
# [(0, 0.5524987), (1, 0.44331774)]
# [(0, 0.011615139), (1, 0.977461), (2, 0.010923894)]
# [(0, 0.041675147), (1, 0.041674454), (2, 0.91665035)]
# [(0, 0.0127218515), (1, 0.79748565), (2, 0.18979253)]
# [(0, 0.20547152), (1, 0.68891674), (2, 0.10561175)]
# [(0, 0.35378936), (1, 0.5510707), (2, 0.09513993)]
# [(0, 0.6425637), (1, 0.21701545), (2, 0.1404209)]
# [(0, 0.8789803), (1, 0.10741034), (2, 0.013609348)]
# [(0, 0.55737084), (1, 0.38604137), (2, 0.056587804)]
# [(0, 0.93349576), (1, 0.042287976), (2, 0.024216248)]
# [(0, 0.020346936), (1, 0.9598921), (2, 0.019760977)]
# [(0, 0.881403), (1, 0.06247716), (2, 0.05611982)]
# [(0, 0.37075916), (1, 0.55386007), (2, 0.075380765)]
# [(0, 0.61020833), (1, 0.37707943), (2, 0.012712276)]
# [(0, 0.2615993), (1, 0.73357123)]
# [(0, 0.46336263), (1, 0.35739836), (2, 0.17923898)]
# [(0, 0.4218892), (1, 0.444492), (2, 0.13361879)]
# [(0, 0.9818818)]
# [(0, 0.05283437), (1, 0.8982826), (2, 0.04888305)]
# [(0, 0.667913), (1, 0.24559866), (2, 0.08648836)]
# [(0, 0.6456654), (1, 0.013419147), (2, 0.34091544)]
# [(0, 0.3716376), (1, 0.62325054)]
# [(0, 0.438344), (1, 0.5048379), (2, 0.05681821)]
# [(0, 0.010309459), (1, 0.96008533), (2, 0.029605206)]
# [(0, 0.47111636), (1, 0.35822913), (2, 0.17065454)]
# [(0, 0.3748764), (1, 0.44226453), (2, 0.18285911)]
# [(0, 0.9812059)]
# [(0, 0.5789277), (1, 0.41007248), (2, 0.010999841)]
# [(0, 0.13563204), (1, 0.70005727), (2, 0.16431071)]
# [(0, 0.16375482), (1, 0.7635497), (2, 0.07269551)]
# [(0, 0.116818905), (1, 0.8689566), (2, 0.014224506)]
# [(0, 0.30854422), (1, 0.39650226), (2, 0.2949535)]
# [(0, 0.49604058), (1, 0.3062213), (2, 0.1977381)]
# [(0, 0.5400107), (1, 0.4412177), (2, 0.018771594)]
# [(0, 0.046581842), (1, 0.9092005), (2, 0.0442177)]
# [(0, 0.72926897), (1, 0.2545165), (2, 0.01621447)]
# [(0, 0.037223138), (1, 0.038063142), (2, 0.9247138)]
# [(0, 0.18941976), (1, 0.7977237), (2, 0.01285651)]
# [(0, 0.022682259), (1, 0.95947677), (2, 0.017840954)]
# [(0, 0.63010764), (1, 0.35079232), (2, 0.019100036)]
# [(0, 0.6500655), (1, 0.34292334)]
# [(0, 0.7807114), (1, 0.2104086)]
# [(0, 0.19597246), (1, 0.79856807)]
# [(0, 0.16482468), (1, 0.75384754), (2, 0.08132776)]
# [(0, 0.32974696), (1, 0.33921164), (2, 0.33104134)]
# ...
# [(0, 0.025985183), (1, 0.9493011), (2, 0.024713743)]
# [(0, 0.196519), (2, 0.79714614)]
# [(0, 0.03412881), (1, 0.9353532), (2, 0.030517958)]
# [(0, 0.11342386), (1, 0.7692293), (2, 0.11734685)]
# [(0, 0.07088505), (1, 0.86243933), (2, 0.06667564)]
# [(0, 0.830214), (1, 0.08644364), (2, 0.083342336)]
# [(0, 0.025376003), (1, 0.9491656), (2, 0.025458409)]
# [(0, 0.06882407), (1, 0.86280346), (2, 0.068372466)]
# [(0, 0.060506716), (1, 0.8838539), (2, 0.055639368)]
# [(0, 0.27354735), (1, 0.71786386)]
# [(0, 0.016676476), (1, 0.43188214), (2, 0.5514414)]
# [(0, 0.038536265), (1, 0.6453582), (2, 0.31610546)]
# [(0, 0.4799714), (1, 0.4773567), (2, 0.04267188)]
# [(0, 0.2868559), (1, 0.31091148), (2, 0.40223268)]
# [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# [(0, 0.8525702), (1, 0.075565726), (2, 0.07186415)]
# [(0, 0.30483928), (1, 0.2864417), (2, 0.40871894)]
# [(0, 0.39088055), (1, 0.50859576), (2, 0.10052368)]
# [(0, 0.5249644), (1, 0.33775678), (2, 0.13727884)]
# [(0, 0.031662535), (1, 0.40965313), (2, 0.55868435)]
# [(0, 0.016940098), (1, 0.9665503), (2, 0.016509589)]
# [(0, 0.9020257), (1, 0.08278383), (2, 0.015190439)]
# [(0, 0.9413927), (1, 0.030624492), (2, 0.027982743)]
# [(0, 0.039066494), (1, 0.9232867), (2, 0.037646852)]
# [(0, 0.47388804), (1, 0.3212613), (2, 0.20485072)]
# [(0, 0.34454364), (1, 0.6258825), (2, 0.029573822)]
# [(0, 0.9547324), (1, 0.025030212), (2, 0.020237291)]
# [(0, 0.03713338), (1, 0.038059585), (2, 0.924807)]
# [(0, 0.9538814), (1, 0.024688045), (2, 0.021430569)]
# [(0, 0.084446624), (1, 0.83219916), (2, 0.08335421)]
# [(0, 0.034350835), (1, 0.931493), (2, 0.034156125)]
# [(0, 0.024104368), (1, 0.9532435), (2, 0.022652123)]
# [(0, 0.17422104), (1, 0.6583598), (2, 0.16741915)]
# [(0, 0.117152415), (1, 0.7706937), (2, 0.112153836)]
# [(0, 0.39917955), (1, 0.5832568), (2, 0.017563717)]
# [(0, 0.045025147), (1, 0.9111215), (2, 0.043853387)]
# [(0, 0.08485922), (1, 0.8289543), (2, 0.08618653)]
# [(0, 0.09142781), (1, 0.8251024), (2, 0.083469816)]
# [(0, 0.9352408), (1, 0.03444407), (2, 0.03031506)]
# [(0, 0.09919776), (1, 0.40677395), (2, 0.49402827)]
# [(0, 0.076314636), (1, 0.85508263), (2, 0.06860277)]
# [(0, 0.2502277), (1, 0.61836964), (2, 0.13140273)]
# [(0, 0.16806333), (1, 0.46220767), (2, 0.36972895)]
# [(0, 0.022310706), (1, 0.95879614), (2, 0.018893104)]
# [(0, 0.050042216), (1, 0.9078059), (2, 0.042151872)]
# [(0, 0.59281033), (1, 0.3746226), (2, 0.032567043)]
# [(0, 0.029647958), (1, 0.66824263), (2, 0.3021094)]
# [(0, 0.02778448), (1, 0.9461621), (2, 0.026053408)]
# [(0, 0.046560653), (1, 0.9098238), (2, 0.043615595)]
# [(0, 0.034818217), (1, 0.9344317), (2, 0.030750066)]
# [(0, 0.087894), (1, 0.82860786), (2, 0.08349815)]
# [(0, 0.027246729), (1, 0.9470959), (2, 0.02565743)]
# [(0, 0.2172117), (1, 0.77012914), (2, 0.01265919)]
# [(0, 0.08573381), (1, 0.82795495), (2, 0.086311236)]
# [(0, 0.035111103), (1, 0.93095165), (2, 0.033937216)]
# [(0, 0.048027664), (1, 0.9094633), (2, 0.042509094)]
# [(0, 0.041789535), (1, 0.043005243), (2, 0.91520524)]
# [(0, 0.056566928), (1, 0.8874853), (2, 0.055947717)]
# [(0, 0.5625941), (2, 0.42971355)]
# [(0, 0.028114416), (1, 0.9491895), (2, 0.022696128)]
# [(0, 0.27518448), (1, 0.037729535), (2, 0.68708605)]
# [(0, 0.13386382), (1, 0.75461465), (2, 0.111521535)]
# [(0, 0.1811669), (1, 0.060197756), (2, 0.75863534)]
# [(0, 0.9630854), (1, 0.019491429), (2, 0.017423194)]
# [(0, 0.040614925), (1, 0.9216493), (2, 0.03773582)]
# [(0, 0.48989913), (1, 0.42634204), (2, 0.083758816)]
# [(0, 0.49118045), (1, 0.48110855), (2, 0.02771097)]
# [(0, 0.45523882), (1, 0.5306434), (2, 0.014117763)]
# [(0, 0.7764822), (1, 0.18558224), (2, 0.03793554)]
# [(0, 0.31936407), (1, 0.6700283), (2, 0.010607552)]
# [(0, 0.9698261), (1, 0.0153644765), (2, 0.014809374)]
# [(1, 0.46006736), (2, 0.5332176)]
# [(0, 0.39610755), (1, 0.57150614), (2, 0.03238631)]
# [(0, 0.6325646), (1, 0.33909503), (2, 0.028340414)]
# [(0, 0.044910103), (1, 0.9125077), (2, 0.042582233)]
# [(0, 0.12466338), (1, 0.8296149), (2, 0.045721766)]
# [(0, 0.034878265), (1, 0.93871623), (2, 0.026405504)]
# [(0, 0.05108563), (1, 0.9156395), (2, 0.03327488)]
# [(0, 0.06574295), (1, 0.8775985), (2, 0.05665857)]
# [(0, 0.9384326), (1, 0.030865652), (2, 0.03070175)]
# [(0, 0.44269875), (1, 0.54413176), (2, 0.013169487)]
# [(0, 0.032251216), (1, 0.937072), (2, 0.03067683)]
# [(0, 0.24834962), (1, 0.6825752), (2, 0.06907511)]
# [(0, 0.31494942), (1, 0.55902237), (2, 0.12602824)]
# [(0, 0.03817414), (1, 0.922452), (2, 0.039373904)]
# [(0, 0.55190957), (1, 0.1618996), (2, 0.28619075)]
# [(0, 0.28695405), (1, 0.7047807)]
# [(0, 0.060088582), (1, 0.8910536), (2, 0.04885778)]
# [(0, 0.916967), (1, 0.043033995), (2, 0.039999)]
# [(0, 0.076923884), (1, 0.8552207), (2, 0.06785544)]
# [(0, 0.38389626), (1, 0.58940935), (2, 0.026694339)]
# [(0, 0.09151571), (1, 0.82495356), (2, 0.08353075)]
# [(0, 0.01818123), (1, 0.09987375), (2, 0.8819451)]
# [(0, 0.01841777), (1, 0.4276021), (2, 0.5539801)]
# [(0, 0.051885966), (1, 0.8993362), (2, 0.04877784)]
# [(0, 0.10055618), (1, 0.8825693), (2, 0.016874554)]
# [(0, 0.04182542), (1, 0.9245642), (2, 0.03361041)]
# [(0, 0.5853758), (1, 0.3973521), (2, 0.017272102)]
# [(0, 0.16935834), (1, 0.6370152), (2, 0.19362645)]
# [(0, 0.0960202), (1, 0.8205753), (2, 0.08340454)]
# [(0, 0.060393065), (1, 0.882018), (2, 0.05758895)]
# [(0, 0.94708574), (1, 0.026331903), (2, 0.02658232)]
# [(0, 0.2529419), (1, 0.7343863), (2, 0.012671801)]
# [(0, 0.6344574), (1, 0.31941122), (2, 0.046131343)]
# [(0, 0.50897336), (1, 0.45979106), (2, 0.031235624)]
# [(0, 0.16388822), (1, 0.8170549), (2, 0.019056914)]
# [(0, 0.06578198), (1, 0.8746031), (2, 0.05961487)]
# [(0, 0.45031264), (1, 0.50136966), (2, 0.04831769)]
# [(0, 0.47062904), (1, 0.5200988)]
# [(0, 0.49881205), (1, 0.48404202), (2, 0.017145883)]
# [(0, 0.9882256)]
# [(0, 0.021573365), (1, 0.95836693), (2, 0.020059682)]
# [(0, 0.03153654), (1, 0.93786293), (2, 0.03060058)]
# [(0, 0.0371338), (1, 0.038061302), (2, 0.9248049)]
# [(0, 0.037333917), (1, 0.03805971), (2, 0.9246063)]
# [(0, 0.35505688), (1, 0.6174796), (2, 0.027463488)]
# [(1, 0.3930122), (2, 0.5972864)]
# [(0, 0.66104084), (1, 0.17225069), (2, 0.16670844)]
# [(0, 0.024519848), (1, 0.9518972), (2, 0.023582976)]
# [(0, 0.6134751), (1, 0.37927157)]
# [(0, 0.851412), (1, 0.08165638), (2, 0.06693164)]
# [(0, 0.51233107), (1, 0.3514748), (2, 0.1361941)]
# [(0, 0.020387642), (1, 0.6984695), (2, 0.28114283)]
# [(0, 0.116305225), (1, 0.8138734), (2, 0.06982137)]
# [(0, 0.087832876), (1, 0.8286413), (2, 0.08352584)]
# [(0, 0.8032785), (1, 0.18188038), (2, 0.014841142)]
# [(0, 0.80656356), (1, 0.18449023)]
# [(0, 0.5631106), (1, 0.4235847), (2, 0.013304736)]
# [(0, 0.9421707), (1, 0.029860707), (2, 0.02796864)]
# [(0, 0.06499717), (1, 0.6624566), (2, 0.27254626)]
# [(0, 0.037381105), (1, 0.03815227), (2, 0.92446667)]
# [(0, 0.06576834), (1, 0.8656241), (2, 0.06860757)]
# [(0, 0.49508896), (1, 0.4947926), (2, 0.010118484)]
# [(0, 0.021189641), (1, 0.8813438), (2, 0.097466625)]
# [(0, 0.03102638), (1, 0.9406781), (2, 0.028295504)]
# [(0, 0.028034164), (1, 0.84903127), (2, 0.122934595)]
# [(0, 0.085475944), (1, 0.828349), (2, 0.08617503)]
# [(0, 0.04294144), (1, 0.91097033), (2, 0.046088234)]
# [(0, 0.8230652), (1, 0.0109573575), (2, 0.16597746)]
# [(0, 0.086448334), (1, 0.10095276), (2, 0.81259894)]
# [(0, 0.06314994), (1, 0.8799426), (2, 0.05690751)]
# [(0, 0.019251656), (1, 0.9057414), (2, 0.07500697)]
# [(0, 0.042797), (1, 0.9198296), (2, 0.037373435)]
# [(0, 0.5768507), (1, 0.40649626), (2, 0.016652994)]
# [(0, 0.01716449), (1, 0.9663901), (2, 0.016445467)]
# [(0, 0.023533463), (1, 0.9483123), (2, 0.028154192)]
# [(0, 0.013053431), (1, 0.765663), (2, 0.22128354)]
# [(0, 0.09015634), (1, 0.3268043), (2, 0.58303934)]
# [(0, 0.8326635), (1, 0.14665572), (2, 0.020680789)]
# [(0, 0.06986444), (1, 0.87402934), (2, 0.05610624)]
# [(0, 0.03621059), (1, 0.4667717), (2, 0.49701768)]
# [(0, 0.16935647), (1, 0.6372165), (2, 0.19342706)]
# [(0, 0.022810087), (1, 0.9593525), (2, 0.017837469)]
# [(0, 0.01960116), (1, 0.027074676), (2, 0.95332414)]
# [(0, 0.026112722), (1, 0.9497978), (2, 0.024089431)]
# [(0, 0.7569386), (1, 0.045025058), (2, 0.19803639)]
# [(0, 0.03874722), (1, 0.9231074), (2, 0.038145453)]
# [(0, 0.036307044), (1, 0.9327385), (2, 0.030954508)]
# [(0, 0.015523085), (1, 0.969531), (2, 0.01494587)]
# [(0, 0.8938915), (1, 0.058225483), (2, 0.047883004)]
# [(0, 0.64139974), (1, 0.3395713), (2, 0.019028999)]
# [(0, 0.16500749), (1, 0.74908924), (2, 0.08590327)]
# [(0, 0.04448257), (1, 0.9130224), (2, 0.042495016)]
# [(0, 0.058009062), (1, 0.88114136), (2, 0.060849607)]
# [(0, 0.040183946), (1, 0.921264), (2, 0.03855206)]
# [(0, 0.10563859), (1, 0.8748704), (2, 0.019490996)]
# [(0, 0.47408414), (1, 0.51942694)]
# [(0, 0.8424334), (1, 0.04300324), (2, 0.1145633)]
# [(0, 0.8789148), (1, 0.06492337), (2, 0.05616192)]
# [(0, 0.038779058), (1, 0.9241047), (2, 0.037116293)]
# [(0, 0.96568567), (1, 0.02575549)]
# [(0, 0.97609407), (1, 0.013274602), (2, 0.010631294)]
# [(0, 0.48185006), (1, 0.22276103), (2, 0.2953889)]
# [(0, 0.0373934), (1, 0.037534643), (2, 0.92507195)]
# [(0, 0.022795707), (1, 0.95366377), (2, 0.023540562)]
# [(0, 0.051434867), (1, 0.90080327), (2, 0.047761865)]
# [(0, 0.5281948), (1, 0.4341322), (2, 0.03767295)]
# [(0, 0.037210878), (1, 0.020166561), (2, 0.94262254)]
# [(0, 0.93607354), (1, 0.03572667), (2, 0.028199786)]
# [(0, 0.0727659), (1, 0.858173), (2, 0.069061086)]
# [(0, 0.27017885), (1, 0.6787602), (2, 0.051061008)]
# [(0, 0.44140384), (1, 0.13262169), (2, 0.4259745)]
# [(0, 0.24292868), (1, 0.6590868), (2, 0.09798454)]
# [(0, 0.17462562), (1, 0.65870106), (2, 0.16667336)]
# [(0, 0.26616123), (1, 0.056404587), (2, 0.67743415)]
# [(0, 0.069843836), (1, 0.8556361), (2, 0.07452005)]
# [(0, 0.026766216), (1, 0.94925255), (2, 0.023981227)]
# [(0, 0.06778487), (1, 0.86097926), (2, 0.07123581)]
# [(0, 0.050440587), (1, 0.90012515), (2, 0.049434252)]
# [(0, 0.11250304), (1, 0.7591714), (2, 0.12832557)]
# [(0, 0.014466753), (1, 0.75711673), (2, 0.22841652)]
# [(0, 0.6233379), (1, 0.36022356), (2, 0.016438482)]
# [(0, 0.9367607), (1, 0.035357863), (2, 0.02788137)]
# [(0, 0.014321458), (1, 0.9715761), (2, 0.014102446)]
# [(0, 0.7736267), (1, 0.0411261), (2, 0.18524717)]
# [(0, 0.027437882), (1, 0.948055), (2, 0.024507083)]
# [(0, 0.035986867), (1, 0.9301392), (2, 0.03387395)]
# [(0, 0.014964346), (1, 0.014542867), (2, 0.97049284)]
# [(0, 0.05156079), (1, 0.898187), (2, 0.05025222)]
# [(0, 0.48952207), (1, 0.49985123), (2, 0.010626666)]
# [(0, 0.5665293), (1, 0.39505714), (2, 0.038413566)]
# [(0, 0.77663213), (1, 0.20542264), (2, 0.01794526)]
# [(0, 0.02833786), (1, 0.9211518), (2, 0.050510347)]
# [(0, 0.029342925), (1, 0.94215363), (2, 0.028503483)]
# [(0, 0.6873217), (1, 0.28977394), (2, 0.022904301)]
# [(0, 0.78154546), (1, 0.18772982), (2, 0.030724717)]
# [(0, 0.05457696), (1, 0.9015281), (2, 0.04389493)]
# [(0, 0.30304065), (1, 0.689841)]
# [(0, 0.021416815), (1, 0.5306195), (2, 0.4479637)]
# [(0, 0.032246653), (1, 0.9365221), (2, 0.031231213)]
# [(0, 0.025375044), (1, 0.949899), (2, 0.02472597)]
# [(0, 0.44443586), (1, 0.5134544), (2, 0.04210978)]
# [(0, 0.13520285), (1, 0.8300082), (2, 0.034788944)]
# [(0, 0.52195895), (1, 0.4592498), (2, 0.01879122)]
# [(0, 0.8910241), (1, 0.06652965), (2, 0.0424462)]
# [(0, 0.03049174), (1, 0.9402178), (2, 0.029290421)]
# [(0, 0.06867907), (1, 0.8575212), (2, 0.07379977)]
# [(1, 0.9247583), (2, 0.06529535)]
# [(0, 0.5880716), (1, 0.38512006), (2, 0.026808338)]
# [(0, 0.026506495), (1, 0.9459033), (2, 0.02759022)]
# [(0, 0.01725137), (1, 0.8579933), (2, 0.12475528)]
# [(0, 0.045571253), (1, 0.6820671), (2, 0.2723617)]
# [(0, 0.019677123), (1, 0.9624715), (2, 0.017851349)]
# [(0, 0.79571337), (1, 0.017550679), (2, 0.18673594)]
# [(0, 0.9042808), (1, 0.02350125), (2, 0.072217986)]
# [(0, 0.5292918), (1, 0.4609064)]
# [(1, 0.9835364)]
# [(0, 0.7693839), (1, 0.1942355), (2, 0.036380533)]
# [(0, 0.056417048), (1, 0.88650864), (2, 0.057074342)]
# [(0, 0.13733296), (1, 0.39349535), (2, 0.46917164)]
# [(0, 0.40548044), (1, 0.5019816), (2, 0.09253796)]
# [(0, 0.037199333), (1, 0.038060952), (2, 0.9247397)]
# [(0, 0.86709225), (1, 0.07341528), (2, 0.05949251)]
# [(0, 0.6522478), (1, 0.33039758), (2, 0.017354589)]
# [(0, 0.045441583), (1, 0.042571668), (2, 0.91198677)]
# [(0, 0.104573056), (1, 0.8100251), (2, 0.08540188)]
# [(0, 0.94639987), (1, 0.029393673), (2, 0.024206456)]
# [(0, 0.016910894), (1, 0.96628827), (2, 0.016800877)]
# [(0, 0.70145214), (1, 0.28384444), (2, 0.014703459)]
# [(0, 0.053325493), (1, 0.661595), (2, 0.28507954)]
# [(0, 0.070119485), (1, 0.86157924), (2, 0.06830124)]
# [(0, 0.45246235), (1, 0.5409836)]
# [(0, 0.05099446), (1, 0.90454805), (2, 0.044457484)]
# [(0, 0.086056046), (1, 0.8559609), (2, 0.057983026)]
# [(0, 0.8612439), (1, 0.06686821), (2, 0.0718879)]
# [(1, 0.56605464), (2, 0.42681885)]
# [(0, 0.0477767), (1, 0.7692738), (2, 0.18294945)]
# [(0, 0.9037383), (2, 0.08724524)]
# [(0, 0.06366554), (1, 0.8784728), (2, 0.057861682)]
# [(0, 0.03229188), (1, 0.93982154), (2, 0.027886525)]
# [(0, 0.83431655), (1, 0.14261098), (2, 0.023072425)]
# [(0, 0.55899924), (1, 0.42689177), (2, 0.014109023)]
# [(0, 0.01290304), (1, 0.20469698), (2, 0.7824)]
# [(0, 0.9592785), (1, 0.020517435), (2, 0.020204054)]
# [(0, 0.04448298), (1, 0.91336954), (2, 0.042147446)]
# [(0, 0.21832308), (1, 0.6947945), (2, 0.08688244)]
# [(0, 0.08377716), (1, 0.88944495), (2, 0.026777912)]
# [(0, 0.06772599), (1, 0.87562495), (2, 0.056649014)]
# [(0, 0.0693334), (1, 0.8623463), (2, 0.068320334)]
# [(0, 0.01885523), (1, 0.9624144), (2, 0.018730415)]
# [(0, 0.42040363), (1, 0.5725702)]
# [(0, 0.0366778), (1, 0.9295618), (2, 0.033760443)]
# [(0, 0.04632228), (1, 0.91159534), (2, 0.042082414)]
# [(0, 0.03407272), (1, 0.9306733), (2, 0.035253942)]
# [(0, 0.3112408), (1, 0.6001425), (2, 0.08861672)]
# [(0, 0.021046905), (1, 0.9578748), (2, 0.02107833)]
# [(0, 0.49799225), (1, 0.0687616), (2, 0.43324617)]
# [(0, 0.018258763), (1, 0.9634965), (2, 0.018244768)]
# [(0, 0.12972245), (1, 0.84391975), (2, 0.026357796)]
# [(0, 0.85630536), (1, 0.01108873), (2, 0.13260594)]
# [(0, 0.016008636), (1, 0.9690116), (2, 0.014979768)]
# [(0, 0.32383797), (1, 0.51849383), (2, 0.1576682)]
# [(0, 0.042419095), (1, 0.92229056), (2, 0.03529033)]
# [(0, 0.4406148), (1, 0.5505925)]
# [(0, 0.8461841), (1, 0.13048491), (2, 0.023330992)]
# [(0, 0.057696167), (1, 0.8841036), (2, 0.058200244)]
# [(0, 0.07080782), (1, 0.8624117), (2, 0.06678054)]
# [(0, 0.08576816), (1, 0.25873896), (2, 0.6554929)]
# [(0, 0.54810226), (1, 0.44494313)]
# [(0, 0.02198315), (1, 0.95809436), (2, 0.019922469)]
# [(0, 0.0703268), (1, 0.8575888), (2, 0.07208437)]
# [(0, 0.9831868)]
# [(0, 0.8515114), (1, 0.010630975), (2, 0.1378576)]
# [(0, 0.44984898), (1, 0.49220803), (2, 0.057942986)]
# [(0, 0.67937356), (1, 0.30746666), (2, 0.013159799)]
# [(0, 0.9614786), (1, 0.020039286), (2, 0.018482117)]
# [(0, 0.011709815), (1, 0.9763864), (2, 0.0119037945)]
# [(0, 0.3120195), (1, 0.62404853), (2, 0.06393192)]
# [(0, 0.07203825), (1, 0.8606874), (2, 0.067274384)]
# [(0, 0.030766977), (1, 0.9397326), (2, 0.029500367)]
# [(0, 0.9256546), (1, 0.041926518), (2, 0.032418855)]
# [(0, 0.02387253), (1, 0.9557042), (2, 0.020423273)]
# [(0, 0.80751425), (1, 0.18064003), (2, 0.011845674)]
# [(0, 0.058973823), (1, 0.88410336), (2, 0.056922834)]
# [(0, 0.051714163), (1, 0.7584818), (2, 0.18980406)]
# [(0, 0.34716612), (1, 0.49461687), (2, 0.15821704)]
# [(0, 0.19065212), (1, 0.019288883), (2, 0.79005903)]
# [(0, 0.32068893), (1, 0.56778246), (2, 0.111528635)]
# [(0, 0.029969526), (1, 0.9435237), (2, 0.026506778)]
# [(0, 0.708392), (1, 0.24807207), (2, 0.043535903)]
# [(0, 0.0184559), (1, 0.05759802), (2, 0.92394614)]
# [(0, 0.028487133), (1, 0.9462285), (2, 0.0252844)]
# [(0, 0.6598173), (1, 0.17181675), (2, 0.16836601)]
# [(0, 0.7601627), (1, 0.18732232), (2, 0.052514955)]
# [(0, 0.06278642), (1, 0.87664896), (2, 0.06056459)]
# [(0, 0.2572618), (1, 0.7290863), (2, 0.013651868)]
# [(0, 0.8128456), (1, 0.012051926), (2, 0.17510246)]
# [(0, 0.072649665), (1, 0.8586036), (2, 0.06874681)]
# [(0, 0.12377182), (1, 0.016243009), (2, 0.8599852)]
# [(0, 0.016169166), (1, 0.015887257), (2, 0.96794355)]
# [(0, 0.6827319), (1, 0.30344054), (2, 0.013827554)]
# [(0, 0.08448918), (1, 0.8475235), (2, 0.06798727)]
# [(0, 0.039553512), (1, 0.92284817), (2, 0.03759831)]
# [(0, 0.016442673), (1, 0.9696996), (2, 0.01385771)]
# [(0, 0.06258503), (1, 0.87749296), (2, 0.059922006)]
# [(0, 0.8758122), (1, 0.02009363), (2, 0.10409421)]

# %%
# Identify top 5 topics

topics_5 = TopicModelEngine(X)
lda_5 = topics_5.LDA_model(num_of_topics=5, 
                           num_passes=10,
                           stop_words=all_stop_words)
topics_5.print_topics(num_of_words=10)
# Out:
# Topic 1: 0.050*"host" + 0.049*"arrival" + 0.049*"days" + 0.039*"reservation" + 0.035*"cancel" + 0.032*"posting" + 0.031*"automate" + 0.011*"stylish" + 0.008*"valley" + 0.008*"en"
# Topic 2: 0.016*"room" + 0.011*"stay" + 0.011*"time" + 0.009*"clean" + 0.008*"bathroom" + 0.008*"host" + 0.008*"night" + 0.007*"first" + 0.007*"experience" + 0.007*"provide"
# Topic 3: 0.033*"host" + 0.029*"clean" + 0.021*"location" + 0.019*"home" + 0.019*"comfortable" + 0.014*"apartment" + 0.013*"easy" + 0.013*"stay" + 0.011*"beautiful" + 0.011*"quiet"
# Topic 4: 0.017*"room" + 0.013*"location" + 0.010*"clean" + 0.009*"street" + 0.008*"parking" + 0.008*"close" + 0.008*"walk" + 0.007*"bed" + 0.007*"price" + 0.007*"host"
# Topic 5: 0.016*"kitchen" + 0.010*"bathroom" + 0.010*"home" + 0.010*"bed" + 0.009*"space" + 0.009*"room" + 0.008*"coffee" + 0.008*"private" + 0.008*"comfortable" + 0.007*"bedroom"

# %%
topics_5.word_cloud(num_of_topics=5)

# %%
# Identify top 10 topics

topics_10 = TopicModelEngine(X)
lda_10 = topics_10.LDA_model(num_of_topics=10, 
                              num_passes=10,
                              stop_words=all_stop_words)
topics_10.print_topics(num_of_words=10)
# Out:
# Topic 1: 0.047*"clean" + 0.040*"host" + 0.029*"location" + 0.029*"home" + 0.026*"comfortable" + 0.024*"quiet" + 0.023*"neighborhood" + 0.019*"close" + 0.015*"beautiful" + 0.014*"easy"
# Topic 2: 0.043*"room" + 0.024*"kitchen" + 0.024*"bed" + 0.023*"bathroom" + 0.016*"clean" + 0.013*"bedroom" + 0.013*"private" + 0.012*"comfortable" + 0.011*"space" + 0.011*"use"
# Topic 3: 0.015*"walk" + 0.012*"away" + 0.011*"home" + 0.010*"city" + 0.010*"minutes" + 0.009*"stay" + 0.009*"location" + 0.009*"close" + 0.009*"time" + 0.009*"10"
# Topic 4: 0.029*"le" + 0.021*"star" + 0.020*"5" + 0.016*"un" + 0.014*"est" + 0.012*"nous" + 0.011*"l" + 0.010*"pour" + 0.009*"brand" + 0.009*"en"
# Topic 5: 0.074*"host" + 0.071*"days" + 0.070*"arrival" + 0.063*"reservation" + 0.058*"cancel" + 0.052*"posting" + 0.050*"automate" + 0.013*"die" + 0.008*"andrew" + 0.008*"day"
# Topic 6: 0.024*"host" + 0.022*"easy" + 0.020*"location" + 0.018*"business" + 0.015*"clean" + 0.015*"trip" + 0.013*"communication" + 0.012*"space" + 0.012*"accommodate" + 0.012*"work"
# Topic 7: 0.012*"coffee" + 0.010*"provide" + 0.010*"water" + 0.008*"room" + 0.008*"parking" + 0.008*"towel" + 0.008*"price" + 0.008*"snack" + 0.007*"new" + 0.007*"find"
# Topic 8: 0.037*"apartment" + 0.024*"walking" + 0.024*"view" + 0.023*"distance" + 0.018*"location" + 0.018*"restaurant" + 0.014*"city" + 0.013*"street" + 0.012*"easy" + 0.012*"within"
# Topic 9: 0.022*"apartment" + 0.019*"need" + 0.017*"respond" + 0.017*"quick" + 0.017*"host" + 0.016*"question" + 0.013*"clean" + 0.012*"make" + 0.010*"location" + 0.010*"stay"
# Topic 10: 0.030*"host" + 0.022*"home" + 0.019*"stay" + 0.017*"room" + 0.016*"amaze" + 0.015*"time" + 0.015*"clean" + 0.014*"comfortable" + 0.014*"friendly" + 0.013*"experience"

# %%
topics_10.word_cloud(num_of_topics=10)
